# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def get_listing_links(page_url):
    response = requests.get(page_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        listings = soup.find('ul', class_='ulListing').find_all('li', class_='listingBox')
        return [listing['linkref'] for listing in listings]
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

# Base URL for the pages
base_url = 'https://www.mubawab.ma/fr/ct/agadir/immobilier-a-vendre-all:esmn:40:esmx:700:sc:apartment-sale,house-sale,villa-sale'

# Initialize an empty list to store all listing links
all_listing_links = []

# Assuming there are 25 pages
for page_number in range(1, 25):
    page_url = f"{base_url}:p:{page_number}"
    links = get_listing_links(page_url)
    all_listing_links.extend(links)
    print(f"Page {page_number}: {len(links)} links collected.")
    
# Save the links to a CSV file
links_df = pd.DataFrame(all_listing_links, columns=['Link'])
links_df.to_csv('listing_links.csv', index=False)
print("Links saved to listing_links.csv")
# Out:
# Page 1: 34 links collected.
# Page 2: 34 links collected.
# Page 3: 34 links collected.
# Page 4: 34 links collected.
# Page 5: 34 links collected.
# Page 6: 34 links collected.
# Page 7: 34 links collected.
# Page 8: 34 links collected.
# Page 9: 34 links collected.
# Page 10: 34 links collected.
# Page 11: 34 links collected.
# Page 12: 34 links collected.
# Page 13: 34 links collected.
# Page 14: 34 links collected.
# Page 15: 34 links collected.
# Page 16: 34 links collected.
# Page 17: 34 links collected.
# Page 18: 34 links collected.
# Page 19: 34 links collected.
# Page 20: 34 links collected.
# Page 21: 34 links collected.
# Page 22: 34 links collected.
# Page 23: 34 links collected.
# Links saved to listing_links.csv

# %%
# Read the CSV file with the listing links
links_df = pd.read_csv('listing_links.csv')
listing_links = links_df['Link'].tolist()

# Initialize lists to store the extracted data
prices = []
quartiers = []
areas = []
rooms = []
bedrooms = []
bathrooms = []
types = []
statuses = []

# Function to extract details from each listing page
def extract_listing_details(link):
    response = requests.get(link)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract price
        price_tag = soup.find('h3', class_='orangeTit')
        price = ''.join(filter(str.isdigit, price_tag.get_text(strip=True))) if price_tag else 'N/A'
        
        # Extract quartier (neighborhood)
        quartier_div = soup.find('div', class_='col-8 vAlignM adBread')
        quartier_tag = quartier_div.find_all('a', class_='darkblue')[-1] if quartier_div else None
        quartier = quartier_tag.get_text(strip=True) if quartier_tag else 'N/A'
        
        # Extract details using icons
        details_div = soup.find('div', class_='disFlex adDetails')
        area, room, bedroom, bathroom = 'N/A', 'N/A', 'N/A', 'N/A'
        if details_div:
            details = details_div.find_all('div', class_='adDetailFeature')
            for detail in details:
                icon = detail.find('i', class_='adDetailFeatureIcon')
                value = detail.find('span').get_text(strip=True)
                if 'icon-triangle' in icon['class']:
                    area = re.findall(r'\d+', value)[0] if value else 'N/A'
                elif 'icon-house-boxes' in icon['class']:
                    room = re.findall(r'\d+', value)[0] if value else 'N/A'
                elif 'icon-bed' in icon['class']:
                    bedroom = re.findall(r'\d+', value)[0] if value else 'N/A'
                elif 'icon-bath' in icon['class']:
                    bathroom = re.findall(r'\d+', value)[0] if value else 'N/A'

                    
        # Extract additional features
        features_div = soup.find('div', class_='adFeatures')
        type_, status = 'N/A', 'N/A'
        if features_div:
            features = features_div.find_all('div', class_='adMainFeature')
            for feature in features:
                label = feature.find('p', class_='adMainFeatureContentLabel').get_text(strip=True)
                value = feature.find('p', class_='adMainFeatureContentValue').get_text(strip=True)
                if label == 'Type de bien':
                    type_ = value
                elif label == 'Etat':
                    status = value

        # Append the data to the lists
        prices.append(price)
        quartiers.append(quartier)
        areas.append(area)
        rooms.append(room)
        bedrooms.append(bedroom)
        bathrooms.append(bathroom)
        types.append(type_)
        statuses.append(status)
    else:
        print(f"Failed to retrieve listing page: {link}. Status code: {response.status_code}")

# Loop through the first few links and extract details
num = 0
for link in listing_links:
    print(f"Extracting details from link {num}")
    extract_listing_details(link)
    num += 1

# Create a DataFrame to store the extracted data
data = pd.DataFrame({
    'Type': types,
    'Quartier': quartiers,
    'Price': prices,
    'Area': areas,
    'Rooms': rooms,
    'Bedrooms': bedrooms,
    'Bathrooms': bathrooms,
    'Status': statuses,
})

# Display the DataFrame
print(data)

# Save the data to a CSV file
data.to_csv('listing_details.csv', index=False)
# Out:
# Extracting details from link 0
# Extracting details from link 1
# Extracting details from link 2
# Extracting details from link 3
# Extracting details from link 4
# Extracting details from link 5
# Extracting details from link 6
# Extracting details from link 7
# Extracting details from link 8
# Extracting details from link 9
# Extracting details from link 10
# Extracting details from link 11
# Extracting details from link 12
# Extracting details from link 13
# Extracting details from link 14
# Extracting details from link 15
# Extracting details from link 16
# Extracting details from link 17
# Extracting details from link 18
# Extracting details from link 19
# Extracting details from link 20
# Extracting details from link 21
# Extracting details from link 22
# Extracting details from link 23
# Extracting details from link 24
# Extracting details from link 25
# Extracting details from link 26
# Extracting details from link 27
# Extracting details from link 28
# Extracting details from link 29
# Extracting details from link 30
# Extracting details from link 31
# Extracting details from link 32
# Extracting details from link 33
# Extracting details from link 34
# Extracting details from link 35
# Extracting details from link 36
# Extracting details from link 37
# Extracting details from link 38
# Extracting details from link 39
# Extracting details from link 40
# Extracting details from link 41
# Extracting details from link 42
# Extracting details from link 43
# Extracting details from link 44
# Extracting details from link 45
# Extracting details from link 46
# Extracting details from link 47
# Extracting details from link 48
# Extracting details from link 49
# Extracting details from link 50
# Extracting details from link 51
# Extracting details from link 52
# Extracting details from link 53
# Extracting details from link 54
# Extracting details from link 55
# Extracting details from link 56
# Extracting details from link 57
# Extracting details from link 58
# Extracting details from link 59
# Extracting details from link 60
# Extracting details from link 61
# Extracting details from link 62
# Extracting details from link 63
# Extracting details from link 64
# Extracting details from link 65
# Extracting details from link 66
# Extracting details from link 67
# Extracting details from link 68
# Extracting details from link 69
# Extracting details from link 70
# Extracting details from link 71
# Extracting details from link 72
# Extracting details from link 73
# Extracting details from link 74
# Extracting details from link 75
# Extracting details from link 76
# Extracting details from link 77
# Extracting details from link 78
# Extracting details from link 79
# Extracting details from link 80
# Extracting details from link 81
# Extracting details from link 82
# Extracting details from link 83
# Extracting details from link 84
# Extracting details from link 85
# Extracting details from link 86
# Extracting details from link 87
# Extracting details from link 88
# Extracting details from link 89
# Extracting details from link 90
# Extracting details from link 91
# Extracting details from link 92
# Extracting details from link 93
# Extracting details from link 94
# Extracting details from link 95
# Extracting details from link 96
# Extracting details from link 97
# Extracting details from link 98
# Extracting details from link 99
# Extracting details from link 100
# Extracting details from link 101
# Extracting details from link 102
# Extracting details from link 103
# Extracting details from link 104
# Extracting details from link 105
# Extracting details from link 106
# Extracting details from link 107
# Extracting details from link 108
# Extracting details from link 109
# Extracting details from link 110
# Extracting details from link 111
# Extracting details from link 112
# Extracting details from link 113
# Extracting details from link 709
# Extracting details from link 710
# Extracting details from link 711
# Extracting details from link 712
# Extracting details from link 713
# Extracting details from link 714
# Extracting details from link 715
# Extracting details from link 716
# Extracting details from link 717
# Extracting details from link 718
# Extracting details from link 719
# Extracting details from link 720
# Extracting details from link 721
# Extracting details from link 722
# Extracting details from link 723
# Extracting details from link 724
# Extracting details from link 725
# Extracting details from link 726
# Extracting details from link 727
# Extracting details from link 728
# Extracting details from link 729
# Extracting details from link 730
# Extracting details from link 731
# Extracting details from link 732
# Extracting details from link 733
# Extracting details from link 734
# Extracting details from link 735
# Extracting details from link 736
# Extracting details from link 737
# Extracting details from link 738
# Extracting details from link 739
# Extracting details from link 740
# Extracting details from link 741
# Extracting details from link 742
# Extracting details from link 743
# Extracting details from link 744
# Extracting details from link 745
# Extracting details from link 746
# Extracting details from link 747
# Extracting details from link 748
# Extracting details from link 749
# Extracting details from link 750
# Extracting details from link 751
# Extracting details from link 752
# Extracting details from link 753
# Extracting details from link 754
# Extracting details from link 755
# Extracting details from link 756
# Extracting details from link 757
# Extracting details from link 758
# Extracting details from link 759
# Extracting details from link 760
# Extracting details from link 761
# Extracting details from link 762
# Extracting details from link 763
# Extracting details from link 764
# Extracting details from link 765
# Extracting details from link 766
# Extracting details from link 767
# Extracting details from link 768
# Extracting details from link 769
# Extracting details from link 770
# Extracting details from link 771
# Extracting details from link 772
# Extracting details from link 773
# Extracting details from link 774
# Extracting details from link 775
# Extracting details from link 776
# Extracting details from link 777
# Extracting details from link 778
# Extracting details from link 779
# Extracting details from link 780
# Extracting details from link 781
# Extracting details from link 782
# Extracting details from link 783
# Extracting details from link 784
# Extracting details from link 785
# Extracting details from link 786
# Extracting details from link 787
# Extracting details from link 788
# Extracting details from link 789
# Extracting details from link 790
# Extracting details from link 791
# Extracting details from link 792
# Extracting details from link 793
# Extracting details from link 794
# Extracting details from link 795
# Extracting details from link 796
# Extracting details from link 797
# Extracting details from link 798
# Extracting details from link 799
# Extracting details from link 800
# Extracting details from link 801
# Extracting details from link 802
# Extracting details from link 803
# Extracting details from link 804
# Extracting details from link 805
# Extracting details from link 806
# Extracting details from link 807
# Extracting details from link 808
# Extracting details from link 809
# Extracting details from link 810
# Extracting details from link 811
# Extracting details from link 812
# Extracting details from link 813
# Extracting details from link 814
#             Type                  Quartier    Price Area Rooms Bedrooms  \
# 0    Appartement                 Hay Houda   546000   63     3        2
# 1    Appartement                 Hay Houda   979000   89     4        3
# 2    Appartement                 Hay Houda  1012000   92     4        3
# 3    Appartement                 Hay Houda   966000   84     4        3
# 4    Appartement                 Hay Houda   957000   87     4        3
# ..           ...                       ...      ...  ...   ...      ...
# 810  Appartement             Hay Mohammadi   630000   64     3        2
# 811        Villa                Hay Dakhla  2600000  222     6        4
# 812       Maison  Zone Industrielle Agadir  1800000  120     3        2
# 813  Appartement                 Hay Houda  1150000  123     3        2
# 814        Villa                    Illigh  1800000  600    10        7
#
#     Bathrooms    Status
# 0           2   Nouveau
# 1           2   Nouveau
# 2           2   Nouveau
# 3           2   Nouveau
# 4           2   Nouveau
# ..        ...       ...
# 810         2   Nouveau
# 811         2  Bon état
# 812         2  Bon état
# 813         2   Nouveau
# 814         6  Bon état
#
# [815 rows x 8 columns]
